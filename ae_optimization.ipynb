# %%
from model.reduce_model import ReduceModel # class with autoencoder

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from plot_settings import * # plot configuration 

ide_plot() #plot for github dark theme

# %%
from hyperopt import hp, fmin, tpe

# %%
def objective(params):
    model = ReduceModel(model="AE", layers=(1169, 500, 200, 10))
    model.train(loss_func="MSE", **params)
    return model.train_results["test_loss"]

# %%
m = ReduceModel(model="AE", layers=(1169, 500, 200, 10))
m.train(100)
# Out:
# 100%|██████████| 100/100 [00:35<00:00,  2.78it/s]
# Epoch 100, Train Loss: 0.00251182304088806
# Epoch 100, Validation Loss: 0.002715406748889522

# %%
m.plot_loss()
