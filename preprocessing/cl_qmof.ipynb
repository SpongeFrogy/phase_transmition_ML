# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import joblib

# %%
data_property_cell = pd.read_csv("../data/qmof_property_cell.csv", index_col=1) # index_col=1 id "filename"
data_property_cell = data_property_cell.drop("Unnamed: 0", axis=1) # drop numbers of rows
property_cell_cols = ["pld", "lcd", "a", "b", "c", "alpha", "betta", "gamma", "volume", "spacegroupNumber"]
data_property_cell = data_property_cell.loc[:,property_cell_cols].rename({"betta": "beta"}, axis=1)

data_linker_mordred = pd.read_csv("../data/mordred_descriptors.csv", index_col=0)

# %%
p = len(data_linker_mordred.values[np.isnan(data_linker_mordred)]) / len(data_linker_mordred) / len(data_linker_mordred.iloc[0])
print(f"Mordred data has {p*100:.2n} % of nan")
# Out:
# Mordred data has 25 % of nan

# %%
data_node = pd.read_csv("../data/node_descriptors.csv", index_col=0)
data_node = data_node.loc[data_node["n_types_metals"] == 1.]
data_node = data_node.loc[:, ['n_metals', 'Atomic_Number', 'Atomic_Weight',
                              'Atomic Radius', 'Mulliken EN', 'polarizability(A^3)', 'electron affinity(kJ/mol)']]

# %%
data_qmof = pd.concat([data_property_cell, data_linker_mordred, data_node], axis=1)
data_qmof.shape
# Out:
# (7463, 1843)

# %%
from pteproc_model import PreprocessingModel

# %%
# p_dorp means we drop columns with more than 5% of nan values
model = PreprocessingModel(p_drop=0.1, threshold=1e-6, normalizer="minmax")

# %%
data_transformed = model.fit_transform(data_qmof)

# %%
data_transformed.shape
# Out:
# (7463, 1018)

# %%
train, test = train_test_split(data_transformed, test_size=0.2, random_state=42)

# %%
train.shape, test.shape
# Out:
# ((5970, 1018), (1493, 1018))

# %%
pd.options.display.max_columns = 100
train
# Out:
#                                            pld       lcd         a         b  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.144681  0.134608  0.099578  0.286691
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.485215  0.566520  0.401228  0.409167
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.180585  0.209831  0.308425  0.269242
# UVUWEP_FSR                            0.044646  0.115070  0.216436  0.319392
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.161454  0.186949  0.212498  0.175937
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.094003  0.090175  0.305691  0.295653
# COWRIR_FSR                            0.042181  0.095206  0.401058  0.387969
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.208717  0.373788  0.411771  0.379289
# GETWEJ_FSR                            0.030842  0.042997  0.113375  0.079831
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.081494  0.105641  0.168626  0.158546
#
#                                              c     alpha      beta     gamma  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.201016  0.580615  0.534957  0.432328
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.476341  0.577087  0.528019  0.441317
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.442703  0.586116  0.526087  0.816238
# UVUWEP_FSR                            0.202759  0.674168  0.561955  0.632461
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.103219  0.551201  0.321590  0.374313
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.322737  0.578144  0.526959  0.441635
# COWRIR_FSR                            0.289401  0.578143  0.526962  0.572850
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.223143  0.690981  0.877699  0.743917
# GETWEJ_FSR                            0.058477  0.578140  0.851515  0.441659
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.091134  0.411433  0.511646  0.298649
#
#                                         volume  spacegroupNumber       ABC  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.026953          0.000000  0.133642
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.172057          0.000000  0.167676
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.084813          0.000000  0.210640
# UVUWEP_FSR                            0.045866          0.004405  0.145213
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.020972          0.000000  0.118580
# ...                                        ...               ...       ...
# SUJREV_FSR                            0.081708          0.264317  0.165031
# COWRIR_FSR                            0.112291          0.057269  0.182664
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.072399          0.048458  0.118899
# GETWEJ_FSR                            0.005776          0.083700  0.121845
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.015039          0.000000  0.139182
#
#                                          ABCGG     nAcid     nBase   SpAbs_A  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.206239  0.142857  0.000000  0.118076
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.228442  0.095238  0.000000  0.148002
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.272545  0.142857  0.000000  0.187116
# UVUWEP_FSR                            0.196820  0.071429  0.000000  0.134647
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.192708  0.095238  0.000000  0.093497
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.219652  0.071429  0.000000  0.154080
# COWRIR_FSR                            0.244133  0.142857  0.000000  0.163604
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.186130  0.142857  0.000000  0.094238
# GETWEJ_FSR                            0.174644  0.071429  0.136364  0.109914
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.222083  0.095238  0.000000  0.113560
#
#                                        SpMax_A  SpDiam_A    SpAD_A   SpMAD_A  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.604166  0.604166  0.118076  0.670207
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.578607  0.578607  0.148002  0.707163
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.791130  0.791130  0.187116  0.803968
# UVUWEP_FSR                            0.580558  0.574646  0.134647  0.812668
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.511651  0.511651  0.093497  0.454142
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.547543  0.547543  0.154080  0.712472
# COWRIR_FSR                            0.601237  0.601237  0.163604  0.720885
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.576908  0.576908  0.094238  0.508999
# GETWEJ_FSR                            0.558498  0.550266  0.109914  0.814610
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.602838  0.602838  0.113560  0.523419
#
#                                        LogEE_A     VE1_A     VE2_A     VE3_A  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.533678  0.277267  0.239129  0.511327
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.580097  0.348260  0.224702  0.567345
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.646908  0.320506  0.155420  0.586413
# UVUWEP_FSR                            0.538382  0.287535  0.250485  0.513762
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.493189  0.266243  0.273743  0.487269
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.542574  0.285168  0.244117  0.520717
# COWRIR_FSR                            0.601716  0.335631  0.187518  0.579181
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.475544  0.245352  0.306190  0.456942
# GETWEJ_FSR                            0.509278  0.275061  0.284310  0.488665
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.539989  0.288112  0.231089  0.522920
#
#                                          VR1_A     VR2_A     VR3_A  nAromAtom  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.005487  0.012885  0.511001   0.076923
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.006866  0.013418  0.545642   0.145299
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.027434  0.053080  0.665612   0.102564
# UVUWEP_FSR                            0.007458  0.016001  0.520766   0.173077
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.004021  0.009644  0.470827   0.000000
# ...                                        ...       ...       ...        ...
# SUJREV_FSR                            0.012153  0.019828  0.533630   0.153846
# COWRIR_FSR                            0.009739  0.018303  0.584324   0.153846
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.004279  0.009668  0.446942   0.000000
# GETWEJ_FSR                            0.004345  0.011680  0.482933   0.076923
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.005174  0.011597  0.511314   0.051282
#
#                                       nAromBond     nAtom  nHeavyAtom  nSpiro  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103    0.066667  0.132530    0.132075     0.0
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105    0.129630  0.140562    0.163522     0.0
# boydwoo_str_m4_Al_o17_o25_acs_sym_95   0.105556  0.178715    0.196541     0.0
# UVUWEP_FSR                             0.155556  0.129518    0.136792     0.0
# boydwoo_str_m3_o12_o19_pcu_sym_169     0.000000  0.084337    0.119497     0.0
# ...                                         ...       ...         ...     ...
# SUJREV_FSR                             0.133333  0.174699    0.160377     0.0
# COWRIR_FSR                             0.133333  0.162651    0.179245     0.0
# boydwoo_str_m3_o5_o22_nbo_sym_100      0.000000  0.090361    0.113208     0.0
# GETWEJ_FSR                             0.066667  0.096386    0.113208     0.0
# boydwoo_str_m3_o1_o10_pcu_sym_160      0.044444  0.100402    0.138365     0.0
#
#                                       nBridgehead   nHetero        nH  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103      0.000000  0.126126  0.117647
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105      0.000000  0.135135  0.088235
# boydwoo_str_m4_Al_o17_o25_acs_sym_95     0.000000  0.126126  0.129902
# UVUWEP_FSR                               0.000000  0.094595  0.102941
# boydwoo_str_m3_o12_o19_pcu_sym_169       0.000000  0.243243  0.019608
# ...                                           ...       ...       ...
# SUJREV_FSR                               0.000000  0.081081  0.176471
# COWRIR_FSR                               0.000000  0.162162  0.117647
# boydwoo_str_m3_o5_o22_nbo_sym_100        0.041667  0.162162  0.044118
# GETWEJ_FSR                               0.000000  0.135135  0.058824
# boydwoo_str_m3_o1_o10_pcu_sym_160        0.000000  0.243243  0.029412
#
#                                             nC        nN        nO        nS  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.107639  0.000000  0.202381  0.000000
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.138889  0.027778  0.142857  0.000000
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.178819  0.000000  0.184524  0.000000
# UVUWEP_FSR                            0.125000  0.083333  0.071429  0.050000
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.048611  0.083333  0.261905  0.066667
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.156250  0.083333  0.071429  0.000000
# COWRIR_FSR                            0.145833  0.000000  0.214286  0.100000
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.072917  0.000000  0.142857  0.000000
# GETWEJ_FSR                            0.083333  0.166667  0.071429  0.000000
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.069444  0.083333  0.238095  0.133333
#
#                                        nP        nF       nCl  nBr        nI  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.0  0.000000  0.000000  0.0  0.000000
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.0  0.095238  0.000000  0.0  0.000000
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.0  0.000000  0.041667  0.0  0.000000
# UVUWEP_FSR                            0.0  0.000000  0.000000  0.0  0.000000
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.0  0.000000  0.000000  0.0  0.000000
# ...                                   ...       ...       ...  ...       ...
# SUJREV_FSR                            0.0  0.000000  0.000000  0.0  0.000000
# COWRIR_FSR                            0.0  0.000000  0.000000  0.0  0.000000
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.0  0.071429  0.000000  0.0  0.333333
# GETWEJ_FSR                            0.0  0.000000  0.000000  0.0  0.000000
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.0  0.000000  0.000000  0.0  0.000000
#
#                                             nX    ATS0dv    ATS1dv    ATS2dv  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.000000  0.179182  0.147633  0.161663
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.066667  0.210303  0.183592  0.195022
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.025000  0.222399  0.217143  0.237034
# UVUWEP_FSR                            0.000000  0.140752  0.135255  0.142481
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.000000  0.205155  0.127756  0.175947
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.000000  0.147530  0.141037  0.130485
# COWRIR_FSR                            0.000000  0.210892  0.150705  0.201694
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.150000  0.158696  0.119130  0.136614
# GETWEJ_FSR                            0.000000  0.144348  0.141850  0.139723
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.000000  0.202837  0.121070  0.197930
#
#                                         ATS3dv    ATS4dv    ATS5dv  ...  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.149132  0.122520  0.060459  ...
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.183193  0.136243  0.082276  ...
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.199247  0.140204  0.108144  ...
# UVUWEP_FSR                            0.110476  0.070354  0.044721  ...
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.113427  0.116843  0.079511  ...
# ...                                        ...       ...       ...  ...
# SUJREV_FSR                            0.099328  0.074653  0.068904  ...
# COWRIR_FSR                            0.158655  0.104497  0.059372  ...
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.117752  0.092166  0.046190  ...
# GETWEJ_FSR                            0.087395  0.057044  0.032245  ...
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.156240  0.148424  0.118687  ...
#
#                                           JGI4      JGI5      JGI6      JGI7  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.344853  0.361689  0.379358  0.000000
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.310576  0.251134  0.371309  0.197293
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.453727  0.342762  0.611015  0.603917
# UVUWEP_FSR                            0.203073  0.371944  0.474613  0.097499
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.243066  0.240260  0.574074  0.000000
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.268986  0.180195  0.367556  0.044379
# COWRIR_FSR                            0.214775  0.346591  0.515556  0.330769
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.450729  0.119048  0.333333  0.000000
# GETWEJ_FSR                            0.167734  0.322222  0.510988  0.310832
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.373528  0.235690  0.269841  0.000000
#
#                                           JGI8      JGI9     JGI10     JGT10  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.000000  0.000000  0.000000  0.563311
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.268141  0.224593  0.157293  0.541440
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.282152  0.516396  0.629630  0.708465
# UVUWEP_FSR                            0.011565  0.054878  0.082305  0.452531
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.000000  0.000000  0.000000  0.683360
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.081633  0.073171  0.000000  0.411599
# COWRIR_FSR                            0.307692  0.356098  0.665021  0.676490
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.000000  0.000000  0.000000  0.763121
# GETWEJ_FSR                            0.421875  0.000000  0.000000  0.454000
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.000000  0.000000  0.000000  0.732819
#
#                                           Diameter        Radius  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   6.000000e-08  3.000000e-08
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   8.666667e-08  4.333333e-08
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  1.000000e-07  5.000000e-08
# UVUWEP_FSR                            8.000000e-08  4.000000e-08
# boydwoo_str_m3_o12_o19_pcu_sym_169    6.000000e-08  3.000000e-08
# ...                                            ...           ...
# SUJREV_FSR                            7.500000e-08  4.000000e-08
# COWRIR_FSR                            1.100000e-07  5.000000e-08
# boydwoo_str_m3_o5_o22_nbo_sym_100     5.000000e-08  2.500000e-08
# GETWEJ_FSR                            7.000000e-08  3.000000e-08
# boydwoo_str_m3_o1_o10_pcu_sym_160     5.333333e-08  2.666667e-08
#
#                                       TopoShapeIndex  PetitjeanIndex  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103         0.750000        0.857143
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105         0.802381        0.889703
# boydwoo_str_m4_Al_o17_o25_acs_sym_95        0.833333        0.909091
# UVUWEP_FSR                                  0.791667        0.883117
# boydwoo_str_m3_o12_o19_pcu_sym_169          0.750000        0.857143
# ...                                              ...             ...
# SUJREV_FSR                                  0.708333        0.828571
# COWRIR_FSR                                  1.000000        1.000000
# boydwoo_str_m3_o5_o22_nbo_sym_100           0.708333        0.828571
# GETWEJ_FSR                                  1.000000        1.000000
# boydwoo_str_m3_o1_o10_pcu_sym_160           0.722222        0.838095
#
#                                           Vabc   VAdjMat     MWC01     MWC02  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.126495  0.575930  0.122667  0.613723
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.146293  0.621223  0.154667  0.654366
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.174082  0.675817  0.202667  0.724820
# UVUWEP_FSR                            0.120160  0.585466  0.136000  0.618705
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.109758  0.533363  0.101333  0.569275
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.156310  0.585466  0.156000  0.609882
# COWRIR_FSR                            0.171183  0.639136  0.168000  0.674533
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.137392  0.515937  0.104000  0.564739
# GETWEJ_FSR                            0.095980  0.559945  0.112000  0.594051
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.127483  0.576959  0.122667  0.622702
#
#                                          MWC03     MWC04     MWC05     MWC06  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.661707  0.702054  0.731793  0.737356
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.693807  0.727353  0.750627  0.751592
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.778441  0.822831  0.857702  0.863703
# UVUWEP_FSR                            0.662948  0.698102  0.725054  0.727937
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.603032  0.642150  0.662795  0.669553
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.643350  0.675580  0.696748  0.699578
# COWRIR_FSR                            0.712919  0.744957  0.768221  0.767918
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.611255  0.656064  0.684078  0.693231
# GETWEJ_FSR                            0.640260  0.676221  0.703830  0.707428
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.664802  0.708987  0.735191  0.742561
#
#                                          MWC07     MWC08     MWC09     MWC10  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.736850  0.736528  0.735894  0.735666
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.746491  0.743385  0.739702  0.737669
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.863889  0.863658  0.863669  0.863675
# UVUWEP_FSR                            0.726056  0.724335  0.722927  0.721859
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.665147  0.666049  0.662887  0.663524
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.695315  0.694117  0.691369  0.690784
# COWRIR_FSR                            0.762720  0.758908  0.755403  0.753004
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.692891  0.694843  0.694418  0.695610
# GETWEJ_FSR                            0.706289  0.704990  0.703971  0.703132
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.739889  0.740431  0.738522  0.738710
#
#                                         TMWC10     SRW02  SRW03     SRW04  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.289988  0.543547    0.0  0.646108
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.317158  0.591601    0.0  0.680649
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.377966  0.649836    0.0  0.766286
# UVUWEP_FSR                            0.294536  0.553971    0.0  0.646801
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.258797  0.498931    0.0  0.600217
# ...                                        ...       ...    ...       ...
# SUJREV_FSR                            0.303100  0.554887    0.0  0.638844
# COWRIR_FSR                            0.332374  0.610640    0.0  0.700295
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.264124  0.481651    0.0  0.598098
# GETWEJ_FSR                            0.271359  0.526605    0.0  0.623652
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.293234  0.544603    0.0  0.653320
#
#                                          SRW05     SRW06    SRW07     SRW08  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.000000  0.720340  0.00000  0.732019
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.000000  0.743461  0.00000  0.745466
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.000000  0.856988  0.00000  0.872751
# UVUWEP_FSR                            0.235948  0.714917  0.30605  0.721701
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.000000  0.665033  0.00000  0.670800
# ...                                        ...       ...      ...       ...
# SUJREV_FSR                            0.000000  0.697628  0.00000  0.698962
# COWRIR_FSR                            0.000000  0.764071  0.00000  0.764192
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.000000  0.678428  0.00000  0.694547
# GETWEJ_FSR                            0.471896  0.692485  0.59179  0.700326
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.000000  0.727477  0.00000  0.737408
#
#                                          SRW09     SRW10    TSRW10        MW  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.000000  0.729469  0.251615  0.087876
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.000000  0.735724  0.276890  0.106636
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.000000  0.869917  0.325253  0.129123
# UVUWEP_FSR                            0.335828  0.715324  0.294937  0.089813
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.000000  0.664277  0.229805  0.088439
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.000000  0.689715  0.264254  0.101005
# COWRIR_FSR                            0.000000  0.752406  0.291565  0.124198
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.000000  0.694451  0.229340  0.177722
# GETWEJ_FSR                            0.637619  0.694782  0.313095  0.072388
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.000000  0.733212  0.256899  0.104219
#
#                                            AMW         WPath      WPol  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.161208  2.061667e-08  0.130288
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.205999  3.993333e-08  0.152284
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.188667  5.393333e-08  0.210660
# UVUWEP_FSR                            0.178531  2.747500e-08  0.121827
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.329173  1.995000e-08  0.087986
# ...                                        ...           ...       ...
# SUJREV_FSR                            0.142215  4.922500e-08  0.129442
# COWRIR_FSR                            0.202951  4.915000e-08  0.172589
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.586363  1.702500e-08  0.147208
# GETWEJ_FSR                            0.201635  1.580000e-08  0.086294
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.324663  2.260000e-08  0.131980
#
#                                        Zagreb1   Zagreb2  mZagreb1  mZagreb2  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.124864  0.122178  0.165260  0.122807
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.156352  0.149624  0.177261  0.147034
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.227470  0.252103  0.192512  0.172254
# UVUWEP_FSR                            0.135179  0.130810  0.099381  0.120927
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.102063  0.089420  0.195387  0.103592
# ...                                        ...       ...       ...       ...
# SUJREV_FSR                            0.151466  0.144754  0.116257  0.149749
# COWRIR_FSR                            0.172638  0.166003  0.201950  0.160401
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.117264  0.122178  0.181136  0.091165
# GETWEJ_FSR                            0.110749  0.104914  0.086255  0.096491
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.130293  0.123063  0.216514  0.120301
#
#                                       n_metals  Atomic_Number  Atomic_Weight  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103   0.000000       0.112360       0.086723
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105   0.090909       0.303371       0.252930
# boydwoo_str_m4_Al_o17_o25_acs_sym_95  0.181818       0.112360       0.086723
# UVUWEP_FSR                            0.000000       0.505618       0.456406
# boydwoo_str_m3_o12_o19_pcu_sym_169    0.000000       0.303371       0.252930
# ...                                        ...            ...            ...
# SUJREV_FSR                            0.000000       0.303371       0.252930
# COWRIR_FSR                            0.000000       0.269663       0.224989
# boydwoo_str_m3_o5_o22_nbo_sym_100     0.090909       0.303371       0.252930
# GETWEJ_FSR                            0.000000       0.887640       0.866592
# boydwoo_str_m3_o1_o10_pcu_sym_160     0.090909       0.303371       0.252930
#
#                                       Atomic Radius  Mulliken EN  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103        0.000000     0.422680
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105        0.133333     0.841924
# boydwoo_str_m4_Al_o17_o25_acs_sym_95       0.000000     0.422680
# UVUWEP_FSR                                 0.238889     0.800687
# boydwoo_str_m3_o12_o19_pcu_sym_169         0.133333     0.841924
# ...                                             ...          ...
# SUJREV_FSR                                 0.133333     0.841924
# COWRIR_FSR                                 0.188889     0.790378
# boydwoo_str_m3_o5_o22_nbo_sym_100          0.133333     0.841924
# GETWEJ_FSR                                 0.200000     0.652921
# boydwoo_str_m3_o1_o10_pcu_sym_160          0.133333     0.841924
#
#                                       polarizability(A^3)  \
# boydwoo_str_m5_Al_o1_o4_sra_sym_103              0.063869
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105              0.029197
# boydwoo_str_m4_Al_o17_o25_acs_sym_95             0.063869
# UVUWEP_FSR                                       0.043796
# boydwoo_str_m3_o12_o19_pcu_sym_169               0.029197
# ...                                                   ...
# SUJREV_FSR                                       0.029197
# COWRIR_FSR                                       0.049270
# boydwoo_str_m3_o5_o22_nbo_sym_100                0.029197
# GETWEJ_FSR                                       0.036496
# boydwoo_str_m3_o1_o10_pcu_sym_160                0.029197
#
#                                       electron affinity(kJ/mol)
# boydwoo_str_m5_Al_o1_o4_sra_sym_103                    0.158865
# gmof_Zn2O8N2-DPAC_A-irmof7_A_No1105                    0.014184
# boydwoo_str_m4_Al_o17_o25_acs_sym_95                   0.158865
# UVUWEP_FSR                                             0.000000
# boydwoo_str_m3_o12_o19_pcu_sym_169                     0.014184
# ...                                                         ...
# SUJREV_FSR                                             0.014184
# COWRIR_FSR                                             0.190071
# boydwoo_str_m3_o5_o22_nbo_sym_100                      0.014184
# GETWEJ_FSR                                             0.147518
# boydwoo_str_m3_o1_o10_pcu_sym_160                      0.014184
#
# [5970 rows x 1018 columns]

# %%
train.to_csv("../qmof_datasets/train.csv")
test.to_csv("../qmof_datasets/test.csv")
joblib.dump(model, "../qmof_datasets/scaler.pkl")
# Out:
# ['../qmof_datasets/scaler.pkl']
